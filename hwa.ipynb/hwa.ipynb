# %%
import numpy as np 
from scipy import signal
from matplotlib import pyplot as plt

a = np.array([1, 2.5, 1])
r=signal.correlate(a,a)
w, h = signal.freqz(r)

plt.figure()
plt.plot(w,h)
# Out:
# c:\Users\shahryar\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\cbook\__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
r
# Out:
# array([1.  , 5.  , 8.25, 5.  , 1.  ])

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')
import math
# Out:
# C:\Users\shahryar\AppData\Local\Temp\ipykernel_19084\787617433.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
# Creating vectors X and Y
x = np.linspace(0.2, 0.8, 100)

phi = 1600

h = 2* phi * (3 - 4 * np.cos(x) + np.cos(2*x))

s = ((h - 1)/(h))

fig = plt.figure(figsize = (10, 5))
# Create the plot
plt.plot(x/np.pi, s)

# Show the plot
plt.show()
# plt.xlim([0.2, 1])
